# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ## Extra installation step - if you don't have Node and Playwright on your computer
#
# Next, you need to install NodeJS and Playwright on your computer if you don't already have them. Please see instructions here:
#
# [Node and Playwright setup](../setup/SETUP-node.md)

# %% [markdown]
# ## And now - after Installing Playwright, a heads up for Windows PC Users:
#
# While executing the next few cells, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky! You need to do this AFTER installing Playwright (prior cells)
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out the entire else clause that this line is a part of - see the fragment below. Be sure to have the "pass" statement after the ImportError line.
# 5. Restart the kernel by pressing the "Restart" button above
#
# ```python
#         if sys.platform.startswith("win") and sys.version_info >= (3, 8):
#             import asyncio
#
#             try:
#                 from asyncio import WindowsProactorEventLoopPolicy, WindowsSelectorEventLoopPolicy
#             except ImportError:
#                 pass
#                 # not affected
#            # else:
#             #    if type(asyncio.get_event_loop_policy()) is WindowsProactorEventLoopPolicy:
#                     # WindowsProactorEventLoopPolicy is not compatible with tornado 6
#                     # fallback to the pre-3.8 default of Selector
#                     # asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
# ```
#
# Thank you to student Nicolas for finding this, and to Kalyan, Yaki, Zibin and Bhaskar for confirming that this worked for them! And to Vladislav for the extra pointers.
#
# As an alternative, you can just move to a Python module (which we do anyway in Day 5)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/ipreencekmr/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://ipreencekmr.github.io/resume-builder/"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# ATS Resume Builder Interactive JSON Editor Modify values and apply
# instantly to preview + PDF export. {   "basics": {     "full_name":
# "Prince Kumar Sharma",     "job_title": "Sr. Software Engineer",
# "location": {       "city": "Gurugram",       "state": "HR",
# "country": "IN"     },     "contacts": {       "email":
# "ipreencekmr@gmail.com",       "phone": "+91-8744825823"     },
# "connect": {       "linkedin":
# "https://www.linkedin.com/in/ipreencekmr/",       "github":
# "https://github.com/ipreencekmr",       "portfolio":
# "https://sites.google.com/view/ipreencekmr/home",       "badges":
# "https://www.credly.com/users/ipreencekmr"     }   },
# "professional_summary": "Results-driven software engineer with 14+
# years of experience building scalable applications, optimizing
# performance, and leading cross-functional teams.",   "skills": {
# "title": "Core Skills",     "languages": {       "title": "Programming
# Languages",       "values": [         "JavaScript",
# "TypeScript",         "Python",         "SQL"       ]     },
# "libraries_and_frameworks": {       "title": "Libraries & Frameworks",
# "values": [         "React",         "Node.js",         "One App",
# "Bootstrap",         "Playwright",         "Jest",         "React
# Testing Library",         "Parrot Middleware"       ]     },
# "cloud_technology": {       "title": "Cloud Technologies",
# "values": [         "AWS",         "GCP",         "Hydra"       ]
# },     "container_and_orchestration": {       "title": "Containers &
# Orchestration",       "values": [         "Docker",
# "Kubernetes"       ]     },     "database": {       "title":
# "Databases",       "values": [         "PostgreSQL",         "MySQL"
# ]     },     "tools": {       "title": "Tools & Platforms",
# "values": [         "Git",         "Jenkins",         "Rally",
# "OpenSearch Dashboard",         "Aquila",         "Dynatrace"       ]
# }   },   "work_experience": [     {       "company": "IBM India Pvt
# Ltd",       "location": "Gurugram, HR",       "job_title": "Sr. System
# Analyst",       "employment_type": "Full-time",       "start_date":
# "Jan 2022",       "end_date": "Present",       "responsibilities": [
# "Tasked as the lead engineer for web accessibility audit & fix.",
# "Developed micro front end web application using react, jest, RTL,
# Playwright, ELF, Component Library and various other useful
# libraries."       ],       "technologies": [         "One App",
# "One XP",         "Node.js",         "React",         "Redux",
# "Thunk",         "Hydra",         "Docker"       ]     },     {
# "company": "mCURA Mobile Health Pvt Ltd",       "location": "Gurugram,
# HR",       "job_title": "Sr. Software Engineer",
# "employment_type": "Full-time",       "start_date": "Oct 2016",
# "end_date": "Jan 2022",       "responsibilities": [         "Led and
# mentored a cross-functional engineering team, overseeing task
# distribution, sprint execution, and technical governance.",
# "Architected and developed scalable frontend and mobile application
# solutions aligned with business objectives.",         "Directed end-
# to-end project delivery, from requirement analysis to production
# deployment.",         "Designed and built independent in-house
# operational systems to optimize workflows and improve organizational
# efficiency."       ],       "technologies": [         "Javascript",
# "React",         "Objective-C",         "Bootstrap",         "AWS",
# "Node"       ]     },     {       "company": "Cyberlinks Technologies
# Pvt Ltd",       "location": "Gurugram, HR",       "job_title": "Sr.
# iOS Engineer",       "employment_type": "Full-time",
# "start_date": "Jan 2013",       "end_date": "Oct 2016",
# "responsibilities": [         "Designed and optimized high-performance
# iOS applications, delivering seamless and intuitive user
# experiences.",         "Led end-to-end App Store releases for flagship
# applications including All Dox and Munch Ado.",         "Implemented
# rigorous testing and quality assurance practices to ensure code
# reliability, scalability, and maintainability.",         "Collaborated
# with cross-functional teams to align product functionality with
# business and user requirements."       ],       "technologies": [
# "Objective-C",         "RazorPay",         "Cocoa pods",
# "AppCenter",         "xCode"       ]     },     {       "company":
# "Daffodil Software Pvt Ltd",       "location": "Hissar, HR",
# "job_title": "Associate IT",       "employment_type": "Full-time",
# "start_date": "Jun 2011",       "end_date": "Jan 2013",
# "responsibilities": [         "Delivered multiple production-grade iOS
# applications, including Handy Suggestions, Symphony Space Live, and
# MiPath.",         "Architected and developed scalable frontend and
# mobile application solutions aligned with business objectives.",
# "Provided real-time technical support and issue resolution, minimizing
# downtime and improving operational productivity.",
# "Collaborated with stakeholders to translate functional requirements
# into stable, user-centric mobile experiences."       ],
# "technologies": [         "Objective-C",         "Cocoa pods",
# "AppCenter",         "xCode",         "Javascript",         "PhoneGap"
# ]     }   ],   "education": [     {       "institution": "Liverpool
# John Moores University",       "degree": "Master of Science",
# "field_of_study": "Artificial Intelligence & Machine Learning",
# "start_date": "Jul 2021",       "end_date": "Jun 2023",       "grade":
# "63%"     },     {       "institution": "I.K Gujral Punjab Technical
# University",       "degree": "Bachelor of Science",
# "field_of_study": "Information Technology",       "start_date": "Dec
# 2011",       "end_date": "Nov 2013",       "grade": "73.14%"     }
# ],   "certifications": [     {       "name": "Certified Kubernetes
# Application Developer",       "issuer": "Linux Foundation",
# "level": "Professional",       "date_earned": "Jan 2025",
# "expiration_date": "Jan 2027",       "credential_id":
# "f3fcfc2b-a910-4c5d-a5fa-5f2cde624f15"     },     {       "name":
# "Professional Cloud Architect Certification",       "issuer": "Google
# Cloud",       "level": "Professional",       "date_earned": "Jun
# 2024",       "expiration_date": "Jun 2026",       "credential_id":
# "638f5eb7-ebc8-42a6-97ce-58567be8194c"     }   ],   "projects": [
# {       "name": "Transition Engine",       "role": "Full Stack AI
# Engineer",       "description": "Modernized the frontend by migrating
# from Material UI to the Carbon Design System, engineered a Whisper-
# powered audio transcription pipeline, and implemented a robust user
# validation workflow with Alembic-driven database migrations.
# Orchestrated secure audio artifact management via IBM Cloud Storage,
# coordinated delivery through Monday, and deployed workloads on an
# OpenShift cluster. Leveraged PostgreSQL, Milvus vector indexing, and
# the Watson AI platform to ingest, store, and analyze multimodal
# project artifacts.",       "technologies": [         "Python",
# "Podman",         "Fast API",         "Milvus",         "Postgres",
# "Monday"       ],       "link": ""     },     {       "name":
# "Document Finder",       "role": "Full Stack AI Engineer",
# "description": "Engineered an AI-driven document retrieval system
# leveraging vector embeddings, delivering high-precision semantic and
# image-based search through scalable APIs, with Milvus as the high-
# performance vector database backbone.",       "technologies": [
# "Python",         "Podman",         "Fast API",         "Milvus"
# ],       "link": ""     },     {       "name": "Consumer Travel
# Platform",       "role": "Front-End Engineer",       "description":
# "Strengthened application security and accessibility by remediating
# SAST findings and compliance gaps, implemented automated semantic
# versioning and CI/CD pipelines via GitHub Actions, optimized web
# performance through Server-Side Rendering, led design system migration
# (v6→v7), and established robust UI quality gates using Playwright and
# Jest screen testing.",       "technologies": [         "One App",
# "React",         "Github Actions",         "Aquila",         "Jest",
# "RTL",         "Redux",         "OpenSearch Dashboard"       ],
# "link": "https://www.americanexpress.com/en-us/travel/"     },     {
# "name": "Persona API",       "role": "Back-End Engineer",
# "description": "Led end-to-end DevSecOps transformation by migrating
# XLR pipelines to GitHub Actions, eliminating critical vulnerabilities
# (Client-Side Desync, SQL Injection, Web Cache Poisoning), and
# engineering a gated blue/green deployment model with multi-stage
# approvals and automated e1→e2 promotion. Established enterprise-grade
# CI/CD with Karate automation, JUnit/Jacoco coverage reporting,
# semantic-release package publishing, Slack-integrated deployment
# telemetry, secure secrets governance (GitHub Secrets + Vault via
# Helm), reusable artifact workflows with GitHub Pages hosting, and on-
# prem Hydra infrastructure orchestration.",       "technologies": [
# "Spring Boot",         "WebFlux",         "Github Actions",
# "Docker",         "Rally",         "Git"       ],       "link": ""
# },     {       "name": "Select Homes + Retreats",       "role":
# "Front-End Engineer",       "description": "Engineered robust payment
# and trip summary modules, enhanced UX through targeted gap analysis
# and advanced search filters, improved Core Web Vitals (CLS) via
# skeleton loading, optimized performance with lazy loading and code
# splitting, modernized testing by migrating from Enzyme to React
# Testing Library, and implemented Reactlytics for advanced user
# analytics and behavioral tracking.",       "technologies": [
# "One App",         "React",         "Redux",         "Reactlytics",
# "One XP",         "Rally",         "Git"       ],       "link":
# "https://www.americanexpress.com/en-us/travel/vacation-rentals/home/?i
# nav=en_us_menu_travel_book_travel_select_homes_retreats"     },     {
# "name": "Secret Consultation",       "role": "Full-Stack Engineer",
# "description": "Architected a secure full-stack platform with Node.js,
# Express, and MongoDB, delivering encrypted user identification for
# privacy-first anonymity, engineered scalable React-based front-end
# experiences, and implemented AWS-backed CI/CD pipelines to enable
# reliable, zero-downtime deployments.",       "technologies": [
# "Node.js",         "Express",         "Mongo",         "React",
# "AWS"       ],       "link": "https://secretconsultation.com/"     },
# {       "name": "Front Office",       "role": "Full-Stack Engineer",
# "description": "Led end-to-end delivery of an eight-month Front Office
# platform within a five-member cross-functional team, translating
# business requirements into scalable technical architecture. Built
# full-stack capabilities using Vanilla JavaScript, Bootstrap, Node.js,
# Express, and SQL Server, deployed via IIS, and executed under a
# structured Waterfall SDLC with Jira-based governance. Delivered
# mission-critical modules including scheduling, appointment
# orchestration, patient queue management, check-in/out workflows, lab
# test booking, pharmacy order processing, and integrated video
# consultations.",       "technologies": [         "Vanilla JavaScript",
# "HTML",         "Bootstrap"       ],       "link": ""     }   ],
# "awards": [     {       "title": "Growth Award",       "issuer":
# "IBM",       "date": "Aug 2024"     }   ],   "publications": [     {
# "title": "Medicinal Plant Identification by Leaf Structure Using
# Ensemble Methods on Deep Learning Algorithms",       "publisher":
# "IJRAMT",       "date": "Sep 2024",       "link":
# "https://journals.ijramt.com/index.php/ijramt/article/view/2993"     }
# ],   "languages": [     {       "language": "English",
# "proficiency": "Professional Working Proficiency"     },     {
# "language": "Hindi",       "proficiency": "Native"     }   ],
# "keywords": [     "front end development",     "backend development",
# "micro front end architecture",     "microservices",     "performance
# optimization",     "team leadership"   ] } Apply Changes Reset Edit
# JSON and click Apply Changes Prince Kumar Sharma Sr. Software Engineer
# | Gurugram, HR, IN ipreencekmr@gmail.com | +91-8744825823
# https://www.linkedin.com/in/ipreencekmr/ |
# https://github.com/ipreencekmr
# https://www.credly.com/users/ipreencekmr |
# https://sites.google.com/view/ipreencekmr/home Download Resume PDF
# Professional Summary Results-driven software engineer with 14+ years
# of experience building scalable applications, optimizing performance,
# and leading cross-functional teams. Core Skills Programming Languages:
# JavaScript, TypeScript, Python, SQL Libraries & Frameworks: React,
# Node.js, One App, Bootstrap, Playwright, Jest, React Testing Library,
# Parrot Middleware Cloud Technologies: AWS, GCP, Hydra Containers &
# Orchestration: Docker, Kubernetes Databases: PostgreSQL, MySQL Tools &
# Platforms: Git, Jenkins, Rally, OpenSearch Dashboard, Aquila,
# Dynatrace Work Experience Sr. System Analyst - IBM India Pvt Ltd
# Gurugram, HR | Jan 2022 to Present | Full-time Tasked as the lead
# engineer for web accessibility audit & fix. Developed micro front end
# web application using react, jest, RTL, Playwright, ELF, Component
# Library and various other useful libraries. Technologies: One App, One
# XP, Node.js, React, Redux, Thunk, Hydra, Docker Sr. Software Engineer
# - mCURA Mobile Health Pvt Ltd Gurugram, HR | Oct 2016 to Jan 2022 |
# Full-time Led and mentored a cross-functional engineering team,
# overseeing task distribution, sprint execution, and technical
# governance. Architected and developed scalable frontend and mobile
# application solutions aligned with business objectives. Directed end-
# to-end project delivery, from requirement analysis to production
# deployment. Designed and built independent in-house operational
# systems to optimize workflows and improve organizational efficiency.
# Technologies: Javascript, React, Objective-C, Bootstrap, AWS, Node Sr.
# iOS Engineer - Cyberlinks Technologies Pvt Ltd Gurugram, HR | Jan 2013
# to Oct 2016 | Full-time Designed and optimized high-performance iOS
# applications, delivering seamless and intuitive user experiences. Led
# end-to-end App Store releases for flagship applications including All
# Dox and Munch Ado. Implemented rigorous testing and quality assurance
# practices to ensure code reliability, scalability, and
# maintainability. Collaborated with cross-functional teams to align
# product functionality with business and user requirements.
# Technologies: Objective-C, RazorPay, Cocoa pods, AppCenter, xCode
# Associate IT - Daffodil Software Pvt Ltd Hissar, HR | Jun 2011 to Jan
# 2013 | Full-time Delivered multiple production-grade iOS applications,
# including Handy Suggestions, Symphony Space Live, and MiPath.
# Architected and developed scalable frontend and mobile application
# solutions aligned with business objectives. Provided real-time
# technical support and issue resolution, minimizing downtime and
# improving operational productivity. Collaborated with stakeholders to
# translate functional requirements into stable, user-centric mobile
# experiences. Technologies: Objective-C, Cocoa pods, AppCenter, xCode,
# Javascript, PhoneGap Education Master of Science in Artificial
# Intelligence & Machine Learning Liverpool John Moores University Jul
# 2021 to Jun 2023 | Grade: 63% Bachelor of Science in Information
# Technology I.K Gujral Punjab Technical University Dec 2011 to Nov 2013
# | Grade: 73.14% Certifications Certified Kubernetes Application
# Developer - Linux Foundation (Professional) | Earned: Jan 2025 |
# Expires: Jan 2027 | ID: f3fcfc2b-a910-4c5d-a5fa-5f2cde624f15
# Professional Cloud Architect Certification - Google Cloud
# (Professional) | Earned: Jun 2024 | Expires: Jun 2026 | ID:
# 638f5eb7-ebc8-42a6-97ce-58567be8194c Projects Transition Engine Role:
# Full Stack AI Engineer Modernized the frontend by migrating from
# Material UI to the Carbon Design System, engineered a Whisper-powered
# audio transcription pipeline, and implemented a robust user validation
# workflow with Alembic-driven database migrations. Orchestrated secure
# audio artifact management via IBM Cloud Storage, coordinated delivery
# through Monday, and deployed workloads on an OpenShift cluster.
# Leveraged PostgreSQL, Milvus vector indexing, and the Watson AI
# platform to ingest, store, and analyze multimodal project artifacts.
# Technologies: Python, Podman, Fast API, Milvus, Postgres, Monday
# Document Finder Role: Full Stack AI Engineer Engineered an AI-driven
# document retrieval system leveraging vector embeddings, delivering
# high-precision semantic and image-based search through scalable APIs,
# with Milvus as the high-performance vector database backbone.
# Technologies: Python, Podman, Fast API, Milvus Consumer Travel
# Platform Role: Front-End Engineer Strengthened application security
# and accessibility by remediating SAST findings and compliance gaps,
# implemented automated semantic versioning and CI/CD pipelines via
# GitHub Actions, optimized web performance through Server-Side
# Rendering, led design system migration (v6→v7), and established robust
# UI quality gates using Playwright and Jest screen testing.
# Technologies: One App, React, Github Actions, Aquila, Jest, RTL,
# Redux, OpenSearch Dashboard Link: https://www.americanexpress.com/en-
# us/travel/ Persona API Role: Back-End Engineer Led end-to-end
# DevSecOps transformation by migrating XLR pipelines to GitHub Actions,
# eliminating critical vulnerabilities (Client-Side Desync, SQL
# Injection, Web Cache Poisoning), and engineering a gated blue/green
# deployment model with multi-stage approvals and automated e1→e2
# promotion. Established enterprise-grade CI/CD with Karate automation,
# JUnit/Jacoco coverage reporting, semantic-release package publishing,
# Slack-integrated deployment telemetry, secure secrets governance
# (GitHub Secrets + Vault via Helm), reusable artifact workflows with
# GitHub Pages hosting, and on-prem Hydra infrastructure orchestration.
# Technologies: Spring Boot, WebFlux, Github Actions, Docker, Rally, Git
# Select Homes + Retreats Role: Front-End Engineer Engineered robust
# payment and trip summary modules, enhanced UX through targeted gap
# analysis and advanced search filters, improved Core Web Vitals (CLS)
# via skeleton loading, optimized performance with lazy loading and code
# splitting, modernized testing by migrating from Enzyme to React
# Testing Library, and implemented Reactlytics for advanced user
# analytics and behavioral tracking. Technologies: One App, React,
# Redux, Reactlytics, One XP, Rally, Git Link:
# https://www.americanexpress.com/en-us/travel/vacation-
# rentals/home/?inav=en_us_menu_travel_book_travel_select_homes_retreats
# Secret Consultation Role: Full-Stack Engineer Architected a secure
# full-stack platform with Node.js, Express, and MongoDB, delivering
# encrypted user identification for privacy-first anonymity, engineered
# scalable React-based front-end experiences, and implemented AWS-backed
# CI/CD pipelines to enable reliable, zero-downtime deployments.
# Technologies: Node.js, Express, Mongo, React, AWS Link:
# https://secretconsultation.com/ Front Office Role: Full-Stack Engineer
# Led end-to-end delivery of an eight-month Front Office platform within
# a five-member cross-functional team, translating business requirements
# into scalable technical architecture. Built full-stack capabilities
# using Vanilla JavaScript, Bootstrap, Node.js, Express, and SQL Server,
# deployed via IIS, and executed under a structured Waterfall SDLC with
# Jira-based governance. Delivered mission-critical modules including
# scheduling, appointment orchestration, patient queue management,
# check-in/out workflows, lab test booking, pharmacy order processing,
# and integrated video consultations. Technologies: Vanilla JavaScript,
# HTML, Bootstrap Awards Growth Award - IBM (Aug 2024) Publications
# Medicinal Plant Identification by Leaf Structure Using Ensemble
# Methods on Deep Learning Algorithms - IJRAMT (Sep 2024) |
# https://journals.ijramt.com/index.php/ijramt/article/view/2993
# Languages English - Professional Working Proficiency Hindi - Native
# Keywords front end development, backend development, micro front end
# architecture, microservices, performance optimization, team leadership

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
